# %%
import pandas as pd
import numpy as np
import os 
from pathlib import Path
from dataclasses import dataclass

# %%
pwd
# Out:
# 'c:\\Users\\RSR\\PYTHON\\LinearRegression\\Research'

# %%
# -------------------------------------
# STEP 1 DATA INGESTION 
# -------------------------------------

# %%
@dataclass
class DataIngestionConfig:
    root_dir : Path
    source_url : Path
    local_data_file :  Path

# %%
os.chdir("c:\\Users\\RSR\\PYTHON\\LinearRegression\\src")

# %%
pwd
# Out:
# 'c:\\Users\\RSR\\PYTHON\\LinearRegression\\src'

# %%
# url = "https://raw.githubusercontent.com/RS4327/RAWDATA/main/cancer_dataset.csv"
# df = pd.read_csv(url)
# df.head()

from CancerML.Constraints import *
from CancerML.Utils.common import Read_Yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
            self,
            config_filepath=CONFIG_FILE_PATH,
            params_filepath=PARAMS_FILE_PATH
    ):
        print(config_filepath)
        self.config = Read_Yaml(Path("Config/Config.yaml"))
        #self.config = Read_Yaml(Path(config_filepath))
        self.params = Read_Yaml(Path(params_filepath))

    def get_data_ingestion_config(self)->DataIngestionConfig:
        config=self.config.data_ingestion
        data_ingestion_config=DataIngestionConfig(
            root_dir=config.root_dir,
            source_url=config.source_url,
            local_data_file=config.local_data_file

        )
        return data_ingestion_config

# %%
import os 
from  CancerML.Utils.common import *
from CancerML import logger 
import requests

# %%
#!pip install requests

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config=config
    
    def Download_File(self):
        # Step 1: Define raw URL and target paths
        url=self.config.source_url
        download_path=self.config.local_data_file
        extraction_path=self.config.root_dir

        #Creating the Directories
        # os.mkdir(os.path.dirname(download_path,exist_ok=True))
        # os.mkdir(extraction_path,exist_ok=True)
        os.makedirs(os.path.dirname(download_path), exist_ok=True)
        os.makedirs(extraction_path, exist_ok=True)

        #Dowe Load the file
        response=requests.get(url)
        with open(download_path,'wb') as file:
            file.write(response.content)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.Download_File()
    #  data_ingestion.extract_zip_file()
    #data_ingestion.download_csv_from_url()
except Exception as e:
    raise e
# Out:
# Config\Config.yaml
# [2025-12-01 10:06:39,132: INFO: common: YAML loaded successfully: Config\Config.yaml]
# [2025-12-01 10:06:39,146: INFO: common: YAML loaded successfully: params.yaml]

# %%
'''  
Feature	  Meaning	            Description
lcavol  : Log Cancer Volume                     -	Natural logarithm of the estimated tumor volume. Larger values indicate more cancer presence.
lweight	: Log Prostate Weight                   - 	Natural logarithm of the weight of the prostate. Higher weight may relate to enlargement or disease progression.
age	    : Patient Age                           -	Age of the individual (in years). Useful to study how prostate cancer relates to age.
lbph	: Log Benign Prostatic Hyperplasia	    -   Log of the amount of benign prostatic hyperplasia (non-cancerous enlargement). Helps differentiate cancer vs non-cancer effects.
svi	    : Seminal Vesicle Invasion (binary)     -	1 = cancer has invaded seminal vesicles, 0 = no invasion. A strong indicator of cancer spread.
lcp	    : Log Capsular Penetration	            -   Log measure indicating whether cancer has penetrated the prostate capsule. Higher values = more invasion.
gleason	: Gleason Score	Clinical                -   grading of prostate cancer aggressiveness (higher score = more aggressive cancer).
pgg45	: % of Gleason patterns 4 or 5          -	Represents the percentage of more aggressive Gleason patterns present. Higher values indicate more aggressive tumors.
lpsa	: Log Prostate-specific Antigen (PSA)	-   logarithm of PSA level (blood biomarker for prostate cancer). Main predictor variable for modeling.
train	: Training/Test Indicator	            -   1 = row used for training, 0 = used for testing. Helps separate data for model evaluation.


'''
# Out:
# '  \nFeature\t  Meaning\t            Description\nlcavol  : Log Cancer Volume                     -\tNatural logarithm of the estimated tumor volume. Larger values indicate more cancer presence.\nlweight\t: Log Prostate Weight                   - \tNatural logarithm of the weight of the prostate. Higher weight may relate to enlargement or disease progression.\nage\t    : Patient Age                           -\tAge of the individual (in years). Useful to study how prostate cancer relates to age.\nlbph\t: Log Benign Prostatic Hyperplasia\t    -   Log of the amount of benign prostatic hyperplasia (non-cancerous enlargement). Helps differentiate cancer vs non-cancer effects.\nsvi\t    : Seminal Vesicle Invasion (binary)     -\t1 = cancer has invaded seminal vesicles, 0 = no invasion. A strong indicator of cancer spread.\nlcp\t    : Log Capsular Penetration\t            -   Log measure indicating whether cancer has penetrated the prostate capsule. Higher values = more invasion.\ngleason\
# ...

# %%
# -------------------------------------
# STEP 2 VALIDATION 
# -------------------------------------

# %%
# Checking the Missing 
def Validation(df):
    print(f" Checking Missing values for each Feature")
    for col in df.columns:
        print(f" Feature -{col} : Mising values count : {df[col].isnull().sum()}")
       
    duplicated=df.
    
Validation(df)
# Out:
#  Checking Missing values for each Feature
#  Feature -lcavol : Mising values count : 0
#  Feature -lweight : Mising values count : 0
#  Feature -age : Mising values count : 0
#  Feature -lbph : Mising values count : 0
#  Feature -svi : Mising values count : 0
#  Feature -lcp : Mising values count : 0
#  Feature -gleason : Mising values count : 0
#  Feature -pgg45 : Mising values count : 0
#  Feature -lpsa : Mising values count : 0
#  Feature -train : Mising values count : 0
