# %%
import os 
import pandas as pd 
import numpy as np
from pathlib import Path
import yaml

# %%
pwd
# Out:
# 'C:\\Users\\RSR\\PYTHON\\LinearRegression'

# %%
from dataclasses import dataclass

# %%
#Entity -> Config_Entity.py
@dataclass(frozen=True)
class DataValidationConfig:
    root_dir:Path
    data_load_path:Path
    local_data_path: Path 
    STATUS_FILE : Path
    ALL_REQUIRED_FILES: list

# %%
pwd
# Out:
# 'C:\\Users\\RSR\\PYTHON\\LinearRegression'

# %%
os.chdir('c:\\Users\\RSR\\PYTHON\\LinearRegression\\src')

# %%
from CancerML.Constants import *
from CancerML.Utils.common import Read_Yaml,create_directories

# %%
#ConfigurationManager ->ConfigurationManager.py
class ConfigurationManager:
          
    def __init__(

            self,
            cofnig_filepath=CONFIG_FILE_PATH,
            params_filepath=PARAMS_FILE_PATH ):
        
        self.config = Read_Yaml(Path("Config/Config.yaml"))
        self.params =Read_Yaml(params_filepath)

        create_directories([self.config.artifacts_root])
    
    def get_datavalidation_config(self)->DataValidationConfig:
        config=self.config.data_validation

        create_directories([self.config.root_dir])
        data_validation_config=DataValidationConfig(
            root_dir=config.root_dir,
            data_load_path=config.data_load_path,
            local_data_path=config.local_data_path,
            STATUS_FILE=config.STATUS_FILE,
            ALL_REQUIRED_FILES=config.ALL_REQUIRED_FILES 
        )
        return data_validation_config

# %%
class ConfigurationManager:
    def __init__(
            self,
            cofnig_filepath=CONFIG_FILE_PATH,
            params_filepath=PARAMS_FILE_PATH ):
        self.config=Read_Yaml(cofnig_filepath)\
        
        self.params=Read_Yaml(params_filepath)


        create_directories([self.config.artifacts_root])
    
    def get_datavalidation_config(self)->DataValidationConfig:
        config=self.config.data_validation

        create_directories([config.root_dir])
        data_validation_config=DataValidationConfig(
            root_dir=config.root_dir,
            data_load_path=config.data_load_path,
            local_data_path=config.local_data_path,
            STATUS_FILE=config.STATUS_FILE,
            ALL_REQUIRED_FILES=config.ALL_REQUIRED_FILES 
        )
        return data_validation_config

# %%
from CancerML import logger

# %%
class DataValidation:
    def __init__(self,config:DataValidationConfig):
        self.config=config
    
    def Check_files(self)->bool:
        validation_status=None
        file='cancer_dataset.csv'
        if file not in self.config.ALL_REQUIRED_FILES:
              validation_status=False
              with open(self.config.STATUS_FILE,'w') as f:
                    f.write(f"Validation Status :{validation_status}")
        else:
            validation_status=True
            with open(self.config.STATUS_FILE,'w') as f:
                  f.write(f"Validation Status : {validation_status}")
        return validation_status

# %%
try:
    config=ConfigurationManager()
    DataValidationConfig=config.get_datavalidation_config()
    datavaliation=DataValidation(config=DataValidationConfig)
    validation=datavaliation.Check_files()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\RSR\PYTHON\LinearRegression\src\CancerML\Utils\common.py:28, in Read_Yaml(path_to_yaml)
#      27 try:
# ---> 28     with open(path_to_yaml, "r", encoding="utf-8-sig") as yaml_file:
#      29         content = yaml.safe_load(yaml_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Config\\Config.yaml'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 8
#       5     validation=datavaliation.Check_files()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[55], line 2
#       1 try:
# ----> 2     config=ConfigurationManager()
#       3     DataValidationConfig=config.get_datavalidation_config()
#       4     datavaliation=DataValidation(config=DataValidationConfig)
#
# Cell In[52], line 6, in ConfigurationManager.__init__(self, cofnig_filepath, params_filepath)
#       2 def __init__(
#       3         self,
#       4         cofnig_filepath=CONFIG_FILE_PATH,
#       5         params_filepath=PARAMS_FILE_PATH ):
# ----> 6     self.config=Read_Yaml(cofnig_filepath)\
#       8     self.params=Read_Yaml(params_filepath)
#      11     create_directories([self.config.artifacts_root])
#
# File c:\Users\RSR\PYTHON\LinearRegression\src\CancerML\Utils\common.py:38, in Read_Yaml(path_to_yaml)
#      35     return ConfigBox(content)
#      37 except FileNotFoundError:
# ---> 38     raise FileNotFoundError(f"YAML file does not exist → {path_to_yaml}")
#      39 except BoxValueError:
#      40     raise ValueError("YAML content invalid for Box conversion")
#
# FileNotFoundError: YAML file does not exist → Config\Config.yaml
